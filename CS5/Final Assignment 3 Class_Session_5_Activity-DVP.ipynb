# %%
# Create Data Visualizations (DVs) that show Data Composition in Python using an XLSX file. Python 
# Dataset source: U.S. Census Bureau, Current Population Survey, 2021 and 2022 Annual Social and Economic Supplements (CPS ASEC). https://www.census.gov/topics/income-poverty/poverty/data/datasets.html
# The data used in this Activity are people living in poverty in the United States (count in thousands).

# %%
# Import basic libraries (A non-optimized code documentation line.)
import piplite
await piplite.install("openpyxl")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Use the "ExcelFile()" function from a library called "pandas" that was imported as a variable called "pd" to read an excel file called "Class_Session_5.xlsx" and each of its sheets and save it to a variable called "xlsx" for later use.
xlsx = pd.ExcelFile('Class_Session_5_Activity.xlsx')

# %%
# Use the "sheet_names" attribute to output a list of all sheets in the an xlsx file that was assigned to a variable called "xlsx".
xlsx.sheet_names
# If want to, read more about the above xlsx multiple-sheet data inspection steps from the source: https://stackoverflow.com/questions/26521266/using-pandas-to-pdread-excel-for-multiple-worksheets-of-the-same-workbook
# Out:
# ['Ethnicity', 'Gender', 'Age', 'Nativity', 'Region', 'Work', 'Education']

# %%
# Use the "read_excel()" function from a library called "panda" that was imported as a variable called "pd" to read just one sheet to a dataframe assigned to a variable called "df".
df = pd.read_excel(xlsx, sheet_name="Ethnicity") # Experiment with calling in different sheet names from the list of sheets output from the previous step.

# %%
# Call the "df" variable to see what the data for that sheet looks like
df
# Out:
#     Year                          Ethnicity  Poverty
# 0   2020                              White   249083
# 1   2020                White, not Hispanic   195078
# 2   2020                              Black    43694
# 3   2020                              Asian    20352
# 4   2020  American Indian and Alaska Native     3950
# 5   2020                  Two or More Races     9220
# 6   2020                           Hispanic    61769
# 7   2021                              White   248909
# 8   2021                White, not Hispanic   194309
# 9   2021                              Black    43976
# 10  2021                              Asian    20676
# 11  2021  American Indian and Alaska Native     4109
# 12  2021                  Two or More Races     9166
# 13  2021                           Hispanic    62482

# %%
# Do some data engineering to make separate dataframes for years 2020 and 2021
df_2020 = df[df.Year == 2020]
df_2021 = df[df.Year == 2021]

# %%
# Call the "df_2020" variable to see what the data for that sheet looks like
df_2020
# Out:
#    Year                          Ethnicity  Poverty
# 0  2020                              White   249083
# 1  2020                White, not Hispanic   195078
# 2  2020                              Black    43694
# 3  2020                              Asian    20352
# 4  2020  American Indian and Alaska Native     3950
# 5  2020                  Two or More Races     9220
# 6  2020                           Hispanic    61769

# %%
# Call the "df_2021" variable to see what the data for that sheet looks like
df_2021
# Out:
#     Year                          Ethnicity  Poverty
# 7   2021                              White   248909
# 8   2021                White, not Hispanic   194309
# 9   2021                              Black    43976
# 10  2021                              Asian    20676
# 11  2021  American Indian and Alaska Native     4109
# 12  2021                  Two or More Races     9166
# 13  2021                           Hispanic    62482

# %%
# Do some data engineering to define some variables and to create some additional new variables for potential use later. (We might not actually use them in this Activity, but It's good practice.)
ethnicity20 = df_2020['Ethnicity']
poverty20 = df_2020['Poverty']
ethnicity21 = df_2021['Ethnicity']
poverty21 = df_2021['Poverty']

# %%
explode = [0, 0, 0.2, 0.2, 0.5, 0.2, 0.2] # An "explode" list variable is useful in some DVs for when you want to make certain data of the composition to stand out to the viewer. The number of components in your explode list variable must match the number of categories of the variable that you are visualizing. Experiment with the values later to see how it changes the look of your DV.

# %%
# Create a customized pie DV to show the composition of the poverty data for the year 2020. 
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty20, autopct='%.0f%%', explode=explode) # To make sure it shows percentages and to use your "explode" variable.
plt.title("2020 U.S. Poverty by Ethnicity")
plt.ylabel("") # To make sure that ylabel is blank because we don't need one this time.
plt.xlabel("") # To make sure that xlabel is blank because we don't need one this time.
plt.legend(ethnicity20, loc='upper left', framealpha=0.25) # Variations on legend placement and properties to enhance viewability when needed
plt.savefig("Poverty_by_Ethnicity_2020-pie-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Create a copy the code for the 2020 year pie chart on this slide and edit it in all relevant parts to create a pie DV for poverty by the same demographic that you used for 2021. This will allow for visual comparisons between the two data compositions. 
# Don't forget to download your completed .ipynb codebook for later reuse.

# %%
# Create a customized pie DV to show the composition of the poverty data for the year 2020. 
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty21, autopct='%.2f%%', explode=explode) # To make sure it shows percentages and to use your "explode" variable.
plt.title("2021 U.S. Poverty by Ethnicity")
plt.ylabel("") # To make sure that ylabel is blank because we don't need one this time.
plt.xlabel("") # To make sure that xlabel is blank because we don't need one this time.
plt.legend(ethnicity21, loc='upper left', framealpha=0.25) # Variations on legend placement and properties to enhance viewability when needed
plt.savefig("Poverty_by_Ethnicity_2021-pie-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Experiment with customizing your Python DV: https://indianaiproduction.com/matplotlib-pie-chart/
# Experiment with repeating the above code sections (P1, P2, P3) to visualize a different sheet (variable) in the dataset, such as Gender, Age, Nativity, Region, Work, Education.
## Note: this will require you to make several edits in the code to get it to work for that specific variable.
### For example, one edit is that you will have to edit the number of items in the explode set to match the number of variable types.

# %%
# Experiment with making a donut DV for 2020 by repeating the code for a pie chart but "cutting a hole" in the center of it.
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty20, autopct='%.2f%%', explode=explode)
centre_circle = plt.Circle((0, 0), 0.50, fc='white') # draw the circle
fig.gca().add_artist(centre_circle) # Add the circle into the pie
fig = plt.gcf()
plt.title("2020 U.S. Poverty by Ethnicity")
plt.ylabel("")
plt.xlabel("")
plt.legend(ethnicity20, loc='center left', framealpha=0.25)
plt.savefig("Poverty_by_Ethnicity_2020-donut-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Experiment with making a donut DV for 2020 by repeating the code for a pie chart but "cutting a hole" in the center of it.
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty21, autopct='%.0f%%', explode=explode)
centre_circle = plt.Circle((0, 0), 0.70, fc='white') # draw the circle
fig.gca().add_artist(centre_circle) # Add the circle into the pie
fig = plt.gcf()
plt.title("2021 U.S. Poverty by Ethnicity")
plt.ylabel("")
plt.xlabel("")
plt.legend(ethnicity21, loc='center left', framealpha=0.25)
plt.savefig("Poverty_by_Ethnicity_2021-donut-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Experiment with making a basic horizontal bar DV with the data.
New_Colors = ['green', 'blue', 'purple', 'brown', 'black', 'orange', 'gray'] # Data engineer a new variable to define some colors that to use in the DV.
# Experiment with the different colors to customize your DV.

# %%
plt.barh(ethnicity20, poverty20, color=New_Colors) # User your "New_Colors" variable here.
plt.title('2020 U.S. Poverty by Ethnicity')
plt.ylabel('')
plt.xlabel('People Living in Poverty')
plt.savefig("Poverty_by_Ethnicity_2020-bar-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
plt.barh(ethnicity21, poverty21, color=New_Colors) # User your "New_Colors" variable here.
plt.title('2021 U.S. Poverty by Ethnicity')
plt.ylabel('')
plt.xlabel('People Living in Poverty')
plt.savefig("Poverty_by_Ethnicity_2021-bar-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
#End of Code Activity

# %%
#all below was from the previous class Session 4 activity - holdinh for possible reuse.

# %%
# Experiment with ways to customize your Python Line Chart DV here: https://www.python-graph-gallery.com/line-chart/

# %%
# Use the "read_excel()" function from a library called "panda" that was imported as a variable called "pd" to read just one sheet to a dataframe assigned to a variable called "df".
df1 = pd.read_excel(xlsx, sheet_name="Gender")
df1# Experiment with calling in different sheet names from the list of sheets output from the previous step.
# Out:
#    Year  Gender  Poverty
# 0  2020    Male   161565
# 1  2020  Female   166006
# 2  2021    Male   161793
# 3  2021  Female   166398

# %%
# Do some data engineering to make separate dataframes for the year 2020

# %%
# Call the "df1_2020" variable to see what the data for that sheet looks like
df1_2020 = df1[df1.Year == 2020]

# %%
# Do some data engineering to make separate dataframes for the year 2021
df1_2021 = df1[df1.Year == 2021]
#Use the "reset_index" function to create new index for existing data. And use "inplace" attribute to save the changes for the "df1_2021" DataFrame
df1_2021.reset_index(inplace=True)
#Use the "drop" function to delete previous "index" column using "axis=1".
df1_2021 = df1_2021.drop('index', axis=1)
# Call the "df_2021" variable to see what the data for that sheet looks like
df1_2021
# Out:
#    Year  Gender  Poverty
# 0  2021    Male   161793
# 1  2021  Female   166398

# %%
# Do some data engineering to define some variables and to create some additional new variables for potential use later. (We might not actually use them in this Activity, but It's good practice.)
gender20 = df1_2020['Gender']
poverty20 = df1_2020['Poverty']
gender21 = df1_2021['Gender']
poverty21 = df1_2021['Poverty']

# %%
# Experiment with making a donut DV for 2020 by repeating the code for a pie chart but "cutting a hole" in the center of it.
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty20, autopct='%.2f%%')
centre_circle = plt.Circle((0, 0), 0.50, fc='white') # draw the circle
fig.gca().add_artist(centre_circle) # Add the circle into the pie
fig = plt.gcf()
plt.title("2020 U.S. Poverty by Gender")
plt.ylabel("")
plt.xlabel("")
plt.legend(gender20, loc='upper left', framealpha=0.25)
plt.savefig("Poverty_by_Gender_2020-donut-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Experiment with making a donut DV for 2020 by repeating the code for a pie chart but "cutting a hole" in the center of it.
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty21, autopct='%.2f%%')
centre_circle = plt.Circle((0, 0), 0.50, fc='white') # draw the circle
fig.gca().add_artist(centre_circle) # Add the circle into the pie
fig = plt.gcf()
plt.title("2021 U.S. Poverty by Gender")
plt.ylabel("")
plt.xlabel("")
plt.legend(gender21, loc='upper left', framealpha=0.25)
plt.savefig("Poverty_by_Gender_2021-donut-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Use the "read_excel()" function from a library called "pandas" that was imported as a variable called "pd" to read just one sheet to a dataframe assigned to a variable called "df".
df2 = pd.read_excel(xlsx, sheet_name="Age")
df2# Experiment with calling in different sheet names from the list of sheets output from the previous step.
# Out:
#    Year                 Age  Poverty
# 0  2020      Under 18 years    73541
# 1  2020      18 to 64 years   199753
# 2  2020  65 years and older    54276
# 3  2021      Under 18 years    72936
# 4  2021      18 to 64 years   199062
# 5  2021  65 years and older    56193

# %%
# Do some data engineering to make separate dataframes for years 2020 and 2021
df2_2020 = df2[df2.Year == 2020]
df2_2021 = df2[df2.Year == 2021]

# %%
# Do some data engineering to define some variables and to create some additional new variables for potential use later. (We might not actually use them in this Activity, but It's good practice.)
age20 = df2_2020['Age']
poverty20 = df2_2020['Poverty']
age21 = df2_2021['Age']
poverty21 = df2_2021['Poverty']

# %%
explode2 = [0,0,0.1]

# %%
explode = [0.03,0,0.1] # To slice the perticuler section
colors = ['y','b','g'] # Color of each section
textprops = {"fontsize":15} # Font size of text in pie chart
plt.title("2020 U.S. Poverty by Age Distribution",pad=80,fontsize = 20)
plt.pie(poverty20, # Values
        labels = age20, # Use Labels for each sections
        explode = explode, # Use Explode To slice the particuler section
        colors =colors, # Use "colors" to set Color of each section
        autopct = "%0.2f%%", # Show data in persentage for with 2 decimal point
        shadow = True, #Use shadow to Show shadow of pie chart
        radius = 1.4, # Radius to increase or decrease the size of pie chart 
       startangle = 0, # Start angle of first section
        textprops =textprops)
plt.show()

# %%
# Experiment with making a donut DV for 2020 by repeating the code for a pie chart but "cutting a hole" in the center of it.
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty20, autopct='%.2f%%',explode=explode2)
centre_circle = plt.Circle((0, 0), 0.0, fc='white') # draw the circle
fig.gca().add_artist(centre_circle) # Add the circle into the pie
fig = plt.gcf()
plt.title("2020 U.S. Poverty by Age Distribution")
plt.ylabel("")
plt.xlabel("")
plt.legend(age20, loc='upper left', framealpha=0.25)
plt.savefig("Poverty_by_Age_2020-pie-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show()

# %%
# Experiment with making a donut DV for 2020 by repeating the code for a pie chart but "cutting a hole" in the center of it.
fig, ax = plt.subplots(figsize=(12, 7), subplot_kw=dict(aspect="equal"), dpi= 80)
plt.pie(poverty21, autopct='%.2f%%',explode=explode2)
centre_circle = plt.Circle((0, 0), 0.0, fc='white') # draw the circle
fig.gca().add_artist(centre_circle) # Add the circle into the pie
fig = plt.gcf()
plt.title("2021 U.S. Poverty by Age Distribution")
plt.ylabel("")
plt.xlabel("")
plt.legend(age21, loc='upper left', framealpha=0.25)
plt.savefig("Poverty_by_Age_2021-pie-Python.png") # Use the "savefig()" function from the module called "pyplot" from the library called "matplotlib" that was imported as a variable called "plt" to to save your DV as a stand-alone image asset (file) (.png or .jpg, etc.).
plt.show() #Use "show" to display the result of pie chart.

# %%
#idufdnfidfkndsjgufbdsiugksdngiuksgnisukgnsukgnfugnfugjnrujgunsujgnkjnskjsjgsfgsgnsfugfuigsfkdfk

# %%
#Read Class_Session_5_Activity.xlsx(xlsx variable) work sheet and store in df3 
#filter df3 and boolean condition of year 2020 and store into a new variable df3_2020
df3 = pd.read_excel(xlsx, sheet_name="Work")
df3_2020 = df3[df3.Year == 2020]
df3_2020
# Out:
#    Year                 Work  Poverty
# 0  2020            Full-time   100275
# 1  2020  Less than full-time    53383

# %%
# Extract the 'Work' column from df3_2020 DataFrame and store it in Work20
Work20 = df3_2020['Work']

# Extract the 'Poverty' column from df3_2020 DataFrame and store it in poverty20
poverty20 = df3_2020['Poverty']

# %%
# Create a new figure and axis
#set figure size of 10 inch width and 6 inch height
fig, ax = plt.subplots(figsize=(10, 6))

# Create bar plot
#Work20 provides the labels for x-axis, poverty20 provides the height of each bar
bars = ax.bar(Work20, poverty20, color=['#FC0FC0', '#CCFF00'])

#  Set the label and title for the y-axis
ax.set_ylabel('Poverty Count')
ax.set_title('2020 U.S. Poverty by Work Status')

# Add value labels on top of each bar 
#loop will run two times for each graph and add labels 
for i in range(len(Work20)):
    value = poverty20[i]
    ax.text(i, value, f'{value:,}', ha='center', va='bottom')

#Adjust the layout to prevent overlapping of plot elements
plt.tight_layout()

# Save and show the plot
plt.savefig("Poverty_by_Work_2020_bar-Python.png", dpi=300)
plt.show()

# %%
#filter df3 and boolean condition of year 2021 and store into a new variable df3_2021
df3_2021 = df3[df3.Year == 2021]
#reset the index of df3_2021 and creates a new integer index for the df3_2021 and  inplace=True means the changes are applied directly to df3_2021
df3_2021.reset_index(inplace=True)
#above reset_index create a new index and convert existing index into new column and with drop function we will remove that unwanted column
df3_2021 = df3_2021.drop('index', axis=1)
# print df3_2021 varialble output
df3_2021
# Out:
#    Year                 Work  Poverty
# 0  2021            Full-time   110720
# 1  2021  Less than full-time    42288

# %%
# Extract the 'Work' column from df3_2021 DataFrame and store it in Work21
Work21 = df3_2021['Work']

# Extract the 'Poverty' column from df3_2021 DataFrame and store it in poverty21
poverty21 = df3_2021['Poverty']

# %%
# Create a new figure and axis
#set figure size of 10 inch width and 6 inch height
fig, ax = plt.subplots(figsize=(10, 6))

# Create bar plot
#Work21 provides the labels for x-axis, poverty21 provides the height of each bar
bars = ax.bar(Work21, poverty21, color=['#FFFF00', '#6F00FF'])

#  Set the label and title for the y-axis
ax.set_ylabel('Poverty Count')
ax.set_title('2021 U.S. Poverty by Work Status')

# Add value labels on top of each bar 
#loop will run two times for each graph and add labels 
for i in range(len(Work21)):
    value = poverty21[i]
    ax.text(i, value, f'{value:,}', ha='center', va='bottom')

#Adjust the layout to prevent overlapping of plot elements
plt.tight_layout()

# Save and show the plot
plt.savefig("Poverty_by_Work_2021_bar-Python.png", dpi=300)
plt.show()

# %%
#Read Class_Session_5_Activity.xlsx(xlsx variable) Nativity sheet and store in df4
#filter df4 and boolean condition of year 2020 and store into a new variable df4_2020
df4 = pd.read_excel(xlsx, sheet_name="Nativity")
df4_2020 = df4[df4.Year == 2020]
df4_2020
# Out:
#    Year      Nativity  Poverty
# 0  2020   Native-born   282408
# 1  2020  Foreign-born    45162

# %%
# Extract the 'Nativity' column from df4_2020 DataFrame and store it in Nativity20 and similarly create poverty20 variable
nativity20 = df4_2020['Nativity']
poverty20 = df4_2020['Poverty']

# %%
# set figure size of 12 inch width and 6 inch height
plt.figure(figsize=(12, 6))

# Create a horizontal bar chart 
# nativity values will be on the y-axis 
# poverty values will tell us the length of each bar
plt.barh(nativity20, poverty20, color=['#FF00FF', '#1F51FF'])

# Calculate the total number of people in poverty
# This will be used to calculate percentages
total = sum(poverty20)

# Set the title  and x-axis label of the plot
plt.title('U.S. Poverty by Nativity (2020)')
plt.xlabel('Number of People in Poverty')

#Loop through each item in the nativity list and add and percentage values in the graph
for i in range(len(nativity20)):
    # Get the poverty value for this nativity category
    value = poverty20[i]
    
    # Calculate the percentage this value represents of the total
    percentage = (value / total) * 100
    
    plt.text(value, i, f' {value:,} ({percentage:.1f}%)', va='center')

# prevent overlapping so adjust graph
plt.tight_layout()

# Display the plot
plt.show()

# %%
#filter df4 and boolean condition of year 2021 and store into a new variable df4_2021
df4_2021 = df4[df4.Year == 2021]
df4_2021
# Out:
#    Year      Nativity  Poverty
# 2  2021   Native-born   281383
# 3  2021  Foreign-born    46808

# %%
#filter df4 and boolean condition of year 2021 and store into a new variable df4_2021
df4_2021 = df4[df4.Year == 2021]
#reset the index of df4_2021 and creates a new integer index for the df4_2021 and  inplace=True means the changes are applied directly to df4_2021
df4_2021.reset_index(inplace=True)
#above reset_index create a new index and convert existing index into new column and with drop function we will remove that unwanted column
df4_2021 = df4_2021.drop('index', axis=1)
# print df4_2021 varialble output
df4_2021
# Out:
#    Year      Nativity  Poverty
# 0  2021   Native-born   281383
# 1  2021  Foreign-born    46808

# %%
# Extract the 'Nativity' column from df4_2020 DataFrame and store it in Nativity21 and similarly create poverty21 variable
nativity21 = df4_2021['Nativity']
poverty21 = df4_2021['Poverty']

# %%
# set figure size of 12 inch width and 6 inch height
plt.figure(figsize=(12, 6))

# Create a horizontal bar chart 
# nativity values will be on the y-axis 
# poverty values will tell us the length of each bar
plt.barh(nativity21, poverty21, color=['#39FF14', '#FF4500'])

# Calculate the total number of people in poverty
# This will be used to calculate percentages
total = sum(poverty21)

# Set the title  and x-axis label of the plot
plt.title('U.S. Poverty by Nativity (2021)')
plt.xlabel('Number of People in Poverty')

#Loop through each item in the nativity list and add and percentage values in the graph
for i in range(len(nativity21)):
    # Get the poverty value for this nativity category
    value = poverty21[i]
    
    # Calculate the percentage this value represents of the total
    percentage = (value / total) * 100
    
    plt.text(value, i, f' {value:,} ({percentage:.1f}%)', va='center')

# prevent overlapping so adjust graph
plt.tight_layout()

# Display the plot
plt.show()
