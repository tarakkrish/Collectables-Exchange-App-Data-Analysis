# %%
# Assignment -4 [Module 4-Distributions]

# %%
import piplite # When using the JupyterLite web-based environment, this is needed for installing specific session-based libraries inside of a "wrapper" called "piplite".
await piplite.install("seaborn") # For installing the seaborn library in a piplite wrapper for use in this web-based environment session.
await piplite.install("openpyxl")  # For installing the openpyxl library in a piplite wrapper for use in this web-based environment session.
await piplite.install("matplotlib-venn") # For installing the seaborn library in a piplite wrapper for use in this web-based environment session.

# %%
# Import required libraries
import pandas as pd # For data processing
import seaborn as sns # For plotting
import matplotlib.pyplot as plt # For plotting
import matplotlib as mpl # For plot formatting

# %%
# Use the "ExcelFile()" function from a library called "pandas" that was imported as a variable called "pd" to read an excel file called "O-Collectables Exchange App-D6.xlsx'" and each of its sheets and save it to a variable called "D6" for later use.
D6 = pd.ExcelFile('O-Collectables Exchange App-D6.xlsx')

# %%
# Use the "sheet_names" attribute to output a list of all sheets in the an xlsx file that was assigned to a variable called "D6".
D6.sheet_names
# Out:
# ['Data', 'Data Dictionary']

# %%
# Use the "read_excel()" from a library called "pandas" that was imported as "pd" to save the D6 "Data" sheet as a variable called "D6_data" for later use
D6_data = pd.read_excel(D6, "Data")

# %%
# Use the "head()" function to show the first five rows of the content of D6_data for data inspection.
D6_data.head()
# Out:
#    ID  Q16  Q17  Q18  Q19
# 0   1    2    1    2    4
# 1   2    6    2    2    1
# 2   3    4    2    3    4
# 3   4    2    2    1    1
# 4   5    2    1    2    4

# %%
# Use the "read_excel()" from a library called "pandas" that was imported as "pd" to save the D6 "Data Dictionary" sheet as a variable called "D6_DD" for later use
D6_DD = pd.read_excel(D6, "Data Dictionary")

# %%
# Call the "D6_DD" variable to print the entire contents to the screen for data inspection.
D6_DD
# Out:
#     ID                                         ResponseNO  \
# 0  Q16  How much would you be willing to pay for an ap...
# 1  Q17  How much would you be willing to spend per ord...
# 2  Q18  How much would you be willing to spend for an ...
# 3  Q19  How much would you be willing to spend per mon...
#
#             Unnamed: 2           Unnamed: 3         Unnamed: 4  \
# 0  I would not use (0)    $0.99 or less (1)    $1 to $1.99 (2)
# 1  I would not use (0)    $4.99 or less (1)    $5 to $9.99 (2)
# 2  I would not use (0)  I would not pay (1)  $1.99 or less (2)
# 3  I would not use (0)    $4.99 or less (1)    $5 to $6.99 (2)
#
#           Unnamed: 5       Unnamed: 6       Unnamed: 7      Unnamed: 8
# 0    $2 to $2.99 (3)  $3 to $3.99 (4)  $4 to $4.99 (5)  $5 or more (6)
# 1  $10 to $14.99 (3)  $15 or more (4)              NaN             NaN
# 2    $2 to $3.99 (3)  $4 to $5.99 (4)   $6 or more (5)             NaN
# 3    $7 to $8.99 (3)   $9 or more (4)              NaN             NaN

# %%
# Use the "T" attribute to Transpose the D6_DD dataframe to give another way to read it in an output cell. You decide which is easier for your and your team to understand.
D6_DD.T
# Out:
#                                                             0  \
# ID                                                        Q16
# ResponseNO  How much would you be willing to pay for an ap...
# Unnamed: 2                                I would not use (0)
# Unnamed: 3                                  $0.99 or less (1)
# Unnamed: 4                                    $1 to $1.99 (2)
# Unnamed: 5                                    $2 to $2.99 (3)
# Unnamed: 6                                    $3 to $3.99 (4)
# Unnamed: 7                                    $4 to $4.99 (5)
# Unnamed: 8                                     $5 or more (6)
#
#                                                             1  \
# ID                                                        Q17
# ResponseNO  How much would you be willing to spend per ord...
# Unnamed: 2                                I would not use (0)
# Unnamed: 3                                  $4.99 or less (1)
# Unnamed: 4                                    $5 to $9.99 (2)
# Unnamed: 5                                  $10 to $14.99 (3)
# Unnamed: 6                                    $15 or more (4)
# Unnamed: 7                                                NaN
# Unnamed: 8                                                NaN
#
#                                                             2  \
# ID                                                        Q18
# ResponseNO  How much would you be willing to spend for an ...
# Unnamed: 2                                I would not use (0)
# Unnamed: 3                                I would not pay (1)
# Unnamed: 4                                  $1.99 or less (2)
# Unnamed: 5                                    $2 to $3.99 (3)
# Unnamed: 6                                    $4 to $5.99 (4)
# Unnamed: 7                                     $6 or more (5)
# Unnamed: 8                                                NaN
#
#                                                             3
# ID                                                        Q19
# ResponseNO  How much would you be willing to spend per mon...
# Unnamed: 2                                I would not use (0)
# Unnamed: 3                                  $4.99 or less (1)
# Unnamed: 4                                    $5 to $6.99 (2)
# Unnamed: 5                                    $7 to $8.99 (3)
# Unnamed: 6                                     $9 or more (4)
# Unnamed: 7                                                NaN
# Unnamed: 8                                                NaN

# %%
#Get the "ResponseNO" column from "D6_DD" data to Create list with variable "l"
#Later use that list "l" to rename the "D6_Data" columns
l = D6_DD["ResponseNO"]

# %%
# Use the "rename()" function to create a Python dictionary called "D1_D2_data_renamed_columns" that consists of key-value pairs where the key (left of the colon :) are the column codes labels, and the value (right of the colon :) are the explanation labels for the column names.
D6_data_renamed_columns = D6_data.rename(columns={"Q16": l[0], "Q17": l[1], "Q18": l[2], "Q19": l[3]})
D6_data_renamed_columns
# Out:
#       ID  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 185  186
# 186  187
# 187  188
# 188  189
# 189  190
#
#      How much would you be willing to pay for an app that allows you to buy and sell collectable items?  \
# 0                                                    2
# 1                                                    6
# 2                                                    4
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 185                                                  3
# 186                                                  2
# 187                                                  2
# 188                                                  4
# 189                                                  3
#
#      How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 185                                                  2
# 186                                                  1
# 187                                                  1
# 188                                                  4
# 189                                                  2
#
#      How much would you be willing to spend for an exchange fee per item using an app that allows you to buy and sell collectable items?  \
# 0                                                    2
# 1                                                    2
# 2                                                    3
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 185                                                  1
# 186                                                  2
# 187                                                  2
# 188                                                  2
# 189                                                  3
#
#      How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?
# 0                                                    4
# 1                                                    1
# 2                                                    4
# 3                                                    1
# 4                                                    4
# ..                                                 ...
# 185                                                  2
# 186                                                  2
# 187                                                  1
# 188                                                  4
# 189                                                  4
#
# [190 rows x 5 columns]

# %%
# Use the "to_excel()" function on the "D6_data_renamed_columns" variable holding the dataframe to a separate XLSX file called "D6_data_renamed_columns.xlsx" for later use.
# After this code executes, you will see the new XLSX file show up in the content pane to the left.
D6_data_renamed_columns.to_excel("D6_data_renamed_columns.xlsx")

# %%
#Create a copy of dataset "D6_data_renamed_columns" and assign to "df1" for the use of creating first graph
df1=D6_data_renamed_columns

# %%
result1 = df1.groupby('How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?').size().reset_index(name='count of votes for prime membership')

# %%
#Add new row with value 0
new_row = pd.DataFrame({'How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?':0,'count of votes for prime membership':1},
                                                            index =[0])
result1 = pd.concat([new_row, result1]).reset_index(drop = True)
result1
# Out:
#    How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    count of votes for prime membership
# 0                                    1
# 1                                   57
# 2                                   42
# 3                                   45
# 4                                   46

# %%
result2 = df1.groupby('How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?').size().reset_index(name='count of votes for willing to spent per order')

# %%
result2
# Out:
#    How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    count of votes for willing to spent per order
# 0                                             21
# 1                                             71
# 2                                             73
# 3                                             18
# 4                                              7

# %%
# Section 3. Merge the data sheets of the D1 and D2 datasets by the common ID column (Note: This code will not work until you complete Section 2 above.)
# Use the "merge()" from a library called "pandas" that was imported as "pd" to merge two datasets that were assigned to the variables "D1_data" and "D2_data", respectively, on the common column called "ID".
df1result = result1.merge(result2, left_on='How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?', right_on='How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?')
df1result
# Out:
#    How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    count of votes for prime membership  \
# 0                                    1
# 1                                   57
# 2                                   42
# 3                                   45
# 4                                   46
#
#    How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    count of votes for willing to spent per order
# 0                                             21
# 1                                             71
# 2                                             73
# 3                                             18
# 4                                              7

# %%
# Prepare data for plotting
votes_prime = df1result['count of votes for prime membership']
votes_order = df1result['count of votes for willing to spent per order']
labels = df1result['How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?']

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Create the stacked bar chart for Prime Membership
bottom = 0
colors1 = ['#FF5733', '#33FF57', '#3357FF', '#A333FF', '#FF8C33']
colors = ['#add8e6', '#87ceeb', '#1e90ff', '#4169e1', '#000080']
for i in range(len(votes_prime)):
    ax.bar('Prime Membership', votes_prime[i], bottom=bottom, color=colors[i], label=f'Prime {labels[i]}' if i == 0 else "")
    bottom += votes_prime[i]

# Create the stacked bar chart for Order Spending
bottom = 0

for i in range(len(votes_order)):
    ax.bar('Order Spending', votes_order[i], bottom=bottom, color=colors[i], label=f'Order {labels[i]}' if i == 0 else "")
    bottom += votes_order[i]

# Customize plot
plt.title('Votes for Prime Membership and Order Spending')
plt.xlabel('Spending Type')
plt.ylabel('Count of Votes')

# Create custom legends
legend_prime = [plt.Rectangle((0, 0), 1, 1, color=colors[i]) for i in range(len(labels))]
legend_order = [plt.Rectangle((0, 0), 1, 1, color=colors[i]) for i in range(len(labels))]
legend_label_prime =['I would not use (0)','$4.99 or less (1)','$5 to 6.99 (2)','$7 to 8.99 (3)','$9 or more (4)']
legend_label_order =['I would not use (0)','$4.99 or less (1)','$5 to 9.99 (2)','$10 to 14.99 (3)','$15 or more (4)']	

first_legend = plt.legend(legend_prime, legend_label_prime, title='Prime Membership', loc='upper left', bbox_to_anchor=(1, 0.5))
second_legend = plt.legend(legend_order, legend_label_order, title='Order Spending', loc='upper left', bbox_to_anchor=(1, 0.8))

# Add legends to the plot
ax.add_artist(first_legend)
ax.add_artist(second_legend)

# Adjust layout to fit legends
plt.tight_layout()
plt.savefig("First output.png")

# Show plot
plt.show()

# %%
df = D6_data_renamed_columns.copy()
# Filter rows where Column2 equals 4 and Column4 does not equal 4
only_column2_4 = df[(df['How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?'] == 4) & (df['How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?'] != 4)]

# Filter rows where Column4 equals 4 and Column2 does not equal 4
only_column4_4 = df[(df['How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?'] == 4) & (df['How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?'] != 4)]

# Filter rows where both Column2 and Column4 equal 4
both_column2_4_and_column4_4 = df[(df['How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?'] == 4) & (df['How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?'] == 4)]
only_column2_4
# Out:
#       ID  \
# 47    48
# 52    53
# 73    74
# 76    77
# 141  142
#
#      How much would you be willing to pay for an app that allows you to buy and sell collectable items?  \
# 47                                                   6
# 52                                                   3
# 73                                                   3
# 76                                                   5
# 141                                                  6
#
#      How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 47                                                   4
# 52                                                   4
# 73                                                   4
# 76                                                   4
# 141                                                  4
#
#      How much would you be willing to spend for an exchange fee per item using an app that allows you to buy and sell collectable items?  \
# 47                                                   3
# 52                                                   4
# 73                                                   3
# 76                                                   3
# 141                                                  4
#
#      How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?
# 47                                                   1
# 52                                                   3
# 73                                                   2
# 76                                                   1
# 141                                                  3

# %%
only_column4_4
# Out:
#       ID  \
# 0      1
# 2      3
# 4      5
# 5      6
# 21    22
# 25    26
# 27    28
# 38    39
# 39    40
# 45    46
# 50    51
# 54    55
# 61    62
# 62    63
# 69    70
# 70    71
# 71    72
# 84    85
# 85    86
# 89    90
# 90    91
# 94    95
# 100  101
# 101  102
# 104  105
# 105  106
# 108  109
# 119  120
# 120  121
# 128  129
# 136  137
# 137  138
# 145  146
# 147  148
# 148  149
# 152  153
# 157  158
# 159  160
# 161  162
# 169  170
# 176  177
# 180  181
# 181  182
# 189  190
#
#      How much would you be willing to pay for an app that allows you to buy and sell collectable items?  \
# 0                                                    2
# 2                                                    4
# 4                                                    2
# 5                                                    3
# 21                                                   3
# 25                                                   2
# 27                                                   3
# 38                                                   4
# 39                                                   3
# 45                                                   3
# 50                                                   2
# 54                                                   2
# 61                                                   0
# 62                                                   5
# 69                                                   2
# 70                                                   2
# 71                                                   2
# 84                                                   3
# 85                                                   2
# 89                                                   2
# 90                                                   6
# 94                                                   6
# 100                                                  2
# 101                                                  4
# 104                                                  5
# 105                                                  3
# 108                                                  2
# 119                                                  3
# 120                                                  3
# 128                                                  6
# 136                                                  5
# 137                                                  2
# 145                                                  2
# 147                                                  2
# 148                                                  0
# 152                                                  4
# 157                                                  2
# 159                                                  2
# 161                                                  0
# 169                                                  2
# 176                                                  4
# 180                                                  3
# 181                                                  4
# 189                                                  3
#
#      How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 0                                                    1
# 2                                                    2
# 4                                                    1
# 5                                                    1
# 21                                                   2
# 25                                                   1
# 27                                                   2
# 38                                                   1
# 39                                                   2
# 45                                                   2
# 50                                                   2
# 54                                                   1
# 61                                                   0
# 62                                                   3
# 69                                                   1
# 70                                                   1
# 71                                                   2
# 84                                                   1
# 85                                                   1
# 89                                                   1
# 90                                                   3
# 94                                                   2
# 100                                                  1
# 101                                                  3
# 104                                                  1
# 105                                                  2
# 108                                                  3
# 119                                                  2
# 120                                                  3
# 128                                                  2
# 136                                                  2
# 137                                                  2
# 145                                                  1
# 147                                                  2
# 148                                                  0
# 152                                                  1
# 157                                                  1
# 159                                                  2
# 161                                                  0
# 169                                                  1
# 176                                                  1
# 180                                                  1
# 181                                                  2
# 189                                                  2
#
#      How much would you be willing to spend for an exchange fee per item using an app that allows you to buy and sell collectable items?  \
# 0                                                    2
# 2                                                    3
# 4                                                    2
# 5                                                    2
# 21                                                   3
# 25                                                   2
# 27                                                   2
# 38                                                   1
# 39                                                   2
# 45                                                   3
# 50                                                   2
# 54                                                   2
# 61                                                   0
# 62                                                   3
# 69                                                   2
# 70                                                   2
# 71                                                   2
# 84                                                   2
# 85                                                   1
# 89                                                   2
# 90                                                   3
# 94                                                   4
# 100                                                  2
# 101                                                  3
# 104                                                  2
# 105                                                  2
# 108                                                  1
# 119                                                  1
# 120                                                  2
# 128                                                  2
# 136                                                  3
# 137                                                  0
# 145                                                  2
# 147                                                  2
# 148                                                  0
# 152                                                  3
# 157                                                  2
# 159                                                  2
# 161                                                  0
# 169                                                  4
# 176                                                  2
# 180                                                  2
# 181                                                  3
# 189                                                  3
#
#      How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?
# 0                                                    4
# 2                                                    4
# 4                                                    4
# 5                                                    4
# 21                                                   4
# 25                                                   4
# 27                                                   4
# 38                                                   4
# 39                                                   4
# 45                                                   4
# 50                                                   4
# 54                                                   4
# 61                                                   4
# 62                                                   4
# 69                                                   4
# 70                                                   4
# 71                                                   4
# 84                                                   4
# 85                                                   4
# 89                                                   4
# 90                                                   4
# 94                                                   4
# 100                                                  4
# 101                                                  4
# 104                                                  4
# 105                                                  4
# 108                                                  4
# 119                                                  4
# 120                                                  4
# 128                                                  4
# 136                                                  4
# 137                                                  4
# 145                                                  4
# 147                                                  4
# 148                                                  4
# 152                                                  4
# 157                                                  4
# 159                                                  4
# 161                                                  4
# 169                                                  4
# 176                                                  4
# 180                                                  4
# 181                                                  4
# 189                                                  4

# %%
both_column2_4_and_column4_4
# Out:
#       ID  \
# 56    57
# 188  189
#
#      How much would you be willing to pay for an app that allows you to buy and sell collectable items?  \
# 56                                                   6
# 188                                                  4
#
#      How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 56                                                   4
# 188                                                  4
#
#      How much would you be willing to spend for an exchange fee per item using an app that allows you to buy and sell collectable items?  \
# 56                                                   4
# 188                                                  2
#
#      How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?
# 56                                                   4
# 188                                                  4

# %%
#Use Copy to create copy of dataframe 'D6_data_renamed_columns' and assign to a variable 'df2'.
df2 = D6_data_renamed_columns.copy()
#Use the list selection method to select only two columns: 'How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?' and 'How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?'.
df2 = df2[['How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?','How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?']]
#Use 'head' to check the changes on dataframe 'df2'.
df2
# Out:
#      How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?  \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 185                                                  2
# 186                                                  1
# 187                                                  1
# 188                                                  4
# 189                                                  2
#
#      How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?
# 0                                                    4
# 1                                                    1
# 2                                                    4
# 3                                                    1
# 4                                                    4
# ..                                                 ...
# 185                                                  2
# 186                                                  2
# 187                                                  1
# 188                                                  4
# 189                                                  4
#
# [190 rows x 2 columns]

# %%
new_column_names = {'How much would you be willing to spend per order using an app that allows you to buy and sell collectable items?':'Per Order','How much would you be willing to spend per month for a prime membership to an app that allows you to buy and sell collectable items?':'Per Membership'}
df2.rename(columns=new_column_names,inplace=True)
df2
# Out:
#      Per Order  Per Membership
# 0            1               4
# 1            2               1
# 2            2               4
# 3            2               1
# 4            1               4
# ..         ...             ...
# 185          2               2
# 186          1               2
# 187          1               1
# 188          4               4
# 189          2               4
#
# [190 rows x 2 columns]

# %%
# Count 4 & 4 on both columns
count_4_4 = len(df[(df2['Per Order'] == 4) & (df2['Per Membership'] == 4)])

# Count 4,3 & 3,4 as one row
count_4_3_and_3_4 = len(df[((df2['Per Order'] == 4) & (df2['Per Membership'] == 3)) |
                          ((df2['Per Order'] == 3) & (df2['Per Membership'] == 4))])

# Count 4, less than 3 & less than 3, 4
count_4_less_than_3 = len(df[(df2['Per Order'] == 4) & (df2['Per Membership'] < 3)])
count_less_than_3_4 = len(df[(df2['Per Order'] < 3) & (df2['Per Membership'] == 4)])

# %%
from matplotlib_venn import venn2, venn3

# For simplicity, let's assume we only need two sets (Set A: '4 in Per Order', Set B: '4 in Per Membership')

# Total counts for each set
set_A = count_4_4 + count_4_less_than_3 + count_4_3_and_3_4  # Total '4 in Per Order'
set_B = count_4_4 + count_less_than_3_4 + count_4_3_and_3_4  # Total '4 in Per Membership'

# Overlap counts (common elements in both sets)
overlap_AB = count_4_4  # Count of 4 & 4 on both columns

# Prepare the venn diagram
plt.figure(figsize=(8, 6))
venn2(subsets=(count_4_3_and_3_4, count_4_4, count_less_than_3_4 + count_4_less_than_3),set_colors=('skyblue', 'lightgreen'))
#Add a custom legend
# plt.legend([
#     plt.Line2D([0], [0], color='b', lw=4),
#     plt.Line2D([0], [0], color='orange', lw=4),
#     plt.Line2D([0], [0], color='green', lw=4)
# ], ['4 in Per Order only', '4 in Per Membership only', '4 in both'])
# Add a custom legend
colors = ['skyblue', 'lightgreen', 'lightcoral']
labels = ['4 in Per Order only', '4 in Per Membership only', '4 in both']
handles = [plt.Line2D([0], [0], color=color, lw=4) for color in colors]
plt.legend(handles, labels, loc='upper right')

plt.title("Venn Diagram for '4' in Per Order and Per Membership")
plt.show()

# %%
# Below are previous assignment answers

# %%
df1.columns # To output a list of the column names in the dataset that was assigned to a variable called "df".

# %%
# Programming a histogram in Python using a CSV file - histplot function
plt.ticklabel_format(style = 'plain') # To prevent scientific notation showing up in the Data Visualization (DV).
sns.histplot(df1['How many hours per day do you listen to the radio, including online?']).set(title="Distribution of Individuals' Engagement with Radio", xlabel="Daily Radio listening Hours", ylabel="Number of Individuals'") # To create a histogram using the histplot() function, and adding a chart title, x-axis title, and y-axis title.
# Set x-axis ticks manually to show 9 points using range(0,8)
plt.xticks(ticks=range(0,8,1), labels=labels_xaxis_manual)
plt.xticks(rotation=65) #Rotate x-axis labels by 65 degrees
plt.savefig("Distribution of Individuals' Engagement with Radio-hist.png") # To save the DV to a file. Change it to .jpg is you want a .jpg
plt.show() # To show the plot on the screen.

# %%
# Programming a histogram in Python using a CSV file - histplot function
plt.ticklabel_format(style = 'plain') # To prevent scientific notation showing up in the Data Visualization (DV).
sns.histplot(df1["How many hours per week do you read newspapers, including online?"]).set(title="Distribution of Weekly Newspaper Reading Time", xlabel="Hours per Week", ylabel="Number of Individuals'") # To create a histogram using the histplot() function, and adding a chart title, x-axis title, and y-axis title.
# Set x-axis ticks manually to show 9 points using range(0,8)
plt.xticks(ticks=range(0,8,1), labels=labels_xaxis_manual)
plt.xticks(rotation=65)
plt.savefig("Distribution of Weekly Newspaper Reading Time-hist.png") # To save the DV to a file. Change it to .jpg is you want a .jpg
plt.show() # To show the plot on the screen.

# %%
#Create a copy of dataset "df1" and assign to "df3" for the use of creating further analysis
df3= df1.copy()

# %%
#Use the Replace attribute to replace all hour counts with 1. To get a comparison of People never read newspapers, and people who do.
df3['How many hours per week do you read newspapers, including online?'] = df3['How many hours per week do you read newspapers, including online?'].replace([1, 2, 3, 4, 5, 6, 7], 1)

# %%
plt.ticklabel_format(style = 'plain') # To prevent scientific notation showing up in the Data Visualization (DV).
sns.histplot(df3["How many hours per week do you read newspapers, including online?"]).set(title="Distribution of Reading Newspaper", xlabel="Hours per Day", ylabel="Number of Individuals'") # To create a histogram using the histplot() function, and adding a chart title, x-axis title, and y-axis title.
# Set x-axis ticks manually to show 2 points using range(0,2)
plt.xticks(ticks=range(0,2), labels=['0','>0'])
plt.savefig("Further Total Newspaper Readers over hours-hist.png") # To save the DV to a file. Change it to .jpg is you want a .jpg
plt.show() # To show the plot on the screen.

# %%
"""The histogram graph shows a progressive reduction with increasing hours spent reading newspapers. 
According to the discoveries, persons who read newspapers for less than an hour contribute nearly as much as those who never read."""

# %%
# Programming a histogram in Python using a CSV file - histplot function
plt.ticklabel_format(style = 'plain') # To prevent scientific notation showing up in the Data Visualization (DV).
sns.histplot(df1["How many hours per day do you watch TV, including online?"]).set(title="Distribution of Individuals' Engagement with Television", xlabel="Daily Television Viewing Hours", ylabel="Number of Individuals'") # To create a histogram using the histplot() function, and adding a chart title, x-axis title, and y-axis title.
# Set x-axis ticks manually to show 9 points using range(0,8)
plt.xticks(ticks=range(0,8,1), labels=labels_xaxis_manual)
plt.xticks(rotation=65)
plt.savefig("Distribution of Individuals' Engagement with Television-hist.png") # To save the DV to a file. Change it to .jpg is you want a .jpg
plt.show() # To show the plot on the screen.

# %%
#Create a copy of dataset "df1" and assign to "df2" for the use of creating further analysis
df2 = df1.copy()

# %%
# Use the 'drop' to remove the column called 'ID'.
df2 = df2.drop(columns=['ID'])

# %%
#Use 'columns' to get the existing columns in the data frame 'df2'.
df2.columns

# %%
# Mulitple two columns by 7 to convert the existing per-day data to per-week.
df2['How many hours per day do you watch TV, including online?']=df2['How many hours per day do you watch TV, including online?']*7
df2['How many hours per day do you listen to the radio, including online?']=df2['How many hours per day do you listen to the radio, including online?'] * 7

# %%
# Plotting boxplots with 4 colors and assign them to a variable called 'colors'
colors = ['#FF6347', '#4682B4', '#32CD32', '#FFD700']
box = df2.boxplot(patch_artist=True, return_type='dict')

# Use the for loop to set the facecolor by using the 'set_facecolor' method.
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.title('Total hours spent on media per week', fontsize=16)
plt.ylabel('Hours', fontsize=14)
# Set x-axis ticks manually to show 4 points using a list and label them with another list: "['TV','Radio','Magazines','Newspaper']" 
plt.xticks(ticks=[1, 2, 3, 4], labels=['TV','Radio','Magazines','Newspaper'], rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig("Hours_Spent_on_Media-Boxplot-Python.png") # To save the DV to a file. Change it to .jpg is you want a .jpg
plt.show()# To show the plot on the screen.

# %%
"""The boxplot shows that there is a broad range of variances in TV and newspaper engagement.
It is unambiguous that the maximum contribution of newspapers is smaller than the average contribution of TV in terms of weekly hours,
and a comparable contribution is found for TV and radio."""
